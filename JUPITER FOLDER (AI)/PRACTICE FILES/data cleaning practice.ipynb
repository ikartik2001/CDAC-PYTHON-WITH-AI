# %%
import pandas as pd
import numpy as np

# %%
file=pd.read_csv('world_population.csv')

# %%
file
# Out:
#      Rank CCA3  Country/Territory           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
file.index= range(1,len(file)+1)

# %%
file
# Out:
#      Rank CCA3  Country/Territory           Capital Continent  \
# 1      36  AFG        Afghanistan             Kabul      Asia
# 2     138  ALB            Albania            Tirana    Europe
# 3      34  DZA            Algeria           Algiers    Africa
# 4     213  ASM     American Samoa         Pago Pago   Oceania
# 5     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 230   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 231   172  ESH     Western Sahara          El Aaiún    Africa
# 232    46  YEM              Yemen             Sanaa      Asia
# 233    63  ZMB             Zambia            Lusaka    Africa
# 234    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 1           41128771         38972230         33753499         28189672
# 2            2842321          2866849          2882481          2913399
# ...

# %%
l=file['CCA3'].to_list()

# %%
import seaborn as sns

# %%
sns.barplot(data=file,)
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns

# Load dataset
df = sns.load_dataset('diamonds')

# Create bar plot
sns.barplot(data=df, x='cut', y='price')

# Set plot title and axis labels
plt.title('Diamond Price by Cut')
plt.xlabel('Cut')
plt.ylabel('Price')
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#
# ~\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1284         """Send a complete request to the server."""
# -> 1285         self._send_request(method, url, body, headers, encode_chunked)
#    1286
#
# ~\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1330             body = _encode(body, 'body')
# -> 1331         self.endheaders(body, encode_chunked=encode_chunked)
#    1332
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
x=["Python","c++","java","ruby"]
y=[12,34,56,45]
plt.bar(xlabel,y)
plt.xlabel('languages',fontsize=15)
# Out:
# Text(0.5, 0, 'languages')
