# %%
from bs4 import BeautifulSoup
import requests

# %%
soup=BeautifulSoup

# %%
soup
import pandas as pd

# %%
file = pd.read_csv('Input-coffer.csv')

# %%
file
# Out:
#     URL_ID                                                URL
# 0       37  https://insights.blackcoffer.com/ai-in-healthc...
# 1       38  https://insights.blackcoffer.com/what-if-the-c...
# 2       39  https://insights.blackcoffer.com/what-jobs-wil...
# 3       40  https://insights.blackcoffer.com/will-machine-...
# 4       41  https://insights.blackcoffer.com/will-ai-repla...
# 5       42  https://insights.blackcoffer.com/man-and-machi...
# 6       43  https://insights.blackcoffer.com/in-future-or-...
# 7       45  https://insights.blackcoffer.com/how-machine-l...
# 8       46  https://insights.blackcoffer.com/deep-learning...
# 9       47  https://insights.blackcoffer.com/how-to-protec...
# 10      48  https://insights.blackcoffer.com/how-machines-...
# 11      49  https://insights.blackcoffer.com/ai-human-robo...
# 12      50  https://insights.blackcoffer.com/how-ai-will-c...
# 13      51  https://insights.blackcoffer.com/future-of-wor...
# ...

# %%
url = []

# %%
for index,row in file.iterrows():
    link=row['URL']
    url.append(link)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [67], in <cell line: 1>()
#       1 for index,row in file.iterrows():
#       2     link=row['URL']
# ----> 3     url.append(link)
#
# AttributeError: 'str' object has no attribute 'append'

# %%
url
# Out:
# 'https://insights.blackcoffer.com/ai-in-healthcare-to-improve-patient-outcomes/'

# %%
for url in url:
    response = requests.get(url)
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# Input In [69], in <cell line: 1>()
#       1 for url in url:
# ----> 2     response = requests.get(url)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
# ...

# %%
response

# %%
response.status_code
# Out:
# 200

# %%
soup= BeautifulSoup(data,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html >
# <!--[if IE 8]>    <html class="ie8" lang="en"> <![endif]-->
# <!--[if IE 9]>    <html class="ie9" lang="en"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html lang="en-US">
#  <!--<![endif]-->
#  <head>
#   <title>
#    How machine learning used in finance and banking? | Blackcoffer Insights
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="https://insights.blackcoffer.com/xmlrpc.php" rel="pingback"/>
#   <meta content="max-image-preview:large" name="robots">
#    <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
#    <link href="https://insights.blackcoffer.com/feed/" rel="alternate" title="Blackcoffer Insights » Feed" type="application/rss+xml"/>
#    <link href="https://insights.blackcoffer.com/comments/feed/" rel="alternate" title="Blackcoffer Insights » Comments Feed" type="application/rss+xml"/>
#    <script type="text/javascript">
# ...

# %%
soup.title
# Out:
# <title>How machine learning used in finance and banking? | Blackcoffer Insights</title>

# %%
soup.p
# Out:
# <p class="entry-title td-module-title"><a href="https://insights.blackcoffer.com/ranking-customer-behaviours-for-business-strategy/" rel="bookmark" title="Ranking customer behaviours for business strategy">Ranking customer behaviours for business strategy</a></p>

# %%
soup.a
# Out:
# <a id="login-link-mob">Sign in</a>

# %%
p_tags = soup.find_all('p')
for p in p_tags:
    print(p.text,'1')
# Out:
# Ranking customer behaviours for business strategy 1
# Algorithmic trading for multiple commodities markets, like Forex, Metals, Energy, etc. 1
# Trading Bot for FOREX 1
# Python model for the analysis of sector-specific stock ETFs for investment purposes 1
# Playstore & Appstore to Google Analytics (GA) or Firebase to Google Data Studio Mobile App KPI Dashboard 1
# Google Local Service Ads LSA API To Google BigQuery to Google Data Studio 1
# AI Conversational Bot using RASA 1
# Recommendation System Architecture 1
# Rise of telemedicine and its Impact on Livelihood by 2040 1
# Rise of e-health and its impact on humans by the year 2030 1
# Rise of e-health and its impact on humans by the year 2030 1
# Rise of telemedicine and its Impact on Livelihood by 2040 1
# AI/ML and Predictive Modeling 1
# Solution for Contact Centre Problems 1
# How to Setup Custom Domain for Google App Engine Application? 1
# Code Review Checklist 1
# ...
