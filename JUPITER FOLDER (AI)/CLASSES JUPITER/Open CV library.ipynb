# %%
pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import cv2

# %%
img=cv2.imread('colors.jpg')

# %%
img.shape
# Out:
# (360, 492, 3)

# %% [markdown]
# # plt the image using matplotlib

# %%
plt.imshow(img)   # matplot = r,g,b
                 #opencv=b,g,r

# %%
flags=[i for i in dir(cv2) if i.startswith('COLOR_')]
print(flags)
# Out:
# ['COLOR_BAYER_BG2BGR', 'COLOR_BAYER_BG2BGRA', 'COLOR_BAYER_BG2BGR_EA', 'COLOR_BAYER_BG2BGR_VNG', 'COLOR_BAYER_BG2GRAY', 'COLOR_BAYER_BG2RGB', 'COLOR_BAYER_BG2RGBA', 'COLOR_BAYER_BG2RGB_EA', 'COLOR_BAYER_BG2RGB_VNG', 'COLOR_BAYER_BGGR2BGR', 'COLOR_BAYER_BGGR2BGRA', 'COLOR_BAYER_BGGR2BGR_EA', 'COLOR_BAYER_BGGR2BGR_VNG', 'COLOR_BAYER_BGGR2GRAY', 'COLOR_BAYER_BGGR2RGB', 'COLOR_BAYER_BGGR2RGBA', 'COLOR_BAYER_BGGR2RGB_EA', 'COLOR_BAYER_BGGR2RGB_VNG', 'COLOR_BAYER_GB2BGR', 'COLOR_BAYER_GB2BGRA', 'COLOR_BAYER_GB2BGR_EA', 'COLOR_BAYER_GB2BGR_VNG', 'COLOR_BAYER_GB2GRAY', 'COLOR_BAYER_GB2RGB', 'COLOR_BAYER_GB2RGBA', 'COLOR_BAYER_GB2RGB_EA', 'COLOR_BAYER_GB2RGB_VNG', 'COLOR_BAYER_GBRG2BGR', 'COLOR_BAYER_GBRG2BGRA', 'COLOR_BAYER_GBRG2BGR_EA', 'COLOR_BAYER_GBRG2BGR_VNG', 'COLOR_BAYER_GBRG2GRAY', 'COLOR_BAYER_GBRG2RGB', 'COLOR_BAYER_GBRG2RGBA', 'COLOR_BAYER_GBRG2RGB_EA', 'COLOR_BAYER_GBRG2RGB_VNG', 'COLOR_BAYER_GR2BGR', 'COLOR_BAYER_GR2BGRA', 'COLOR_BAYER_GR2BGR_EA', 'COLOR_BAYER_GR2BGR_VNG', 'COLO
# ...

# %%
fix_img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)

# %% [markdown]
# # read img as grey scale

# %%
img_gray=cv2.imread('colors.jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray,cmap='gray')

# %%
#change size of img

# %%
new_img=cv2.resize(fix_img,(1000,400))

# %%
plt.imshow(new_img)

# %%
#change using width and height

# %%
w_ratio=0.8
h_ratio=0.2
ratio_img=cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio)
plt.imshow(ratio_img)

# %%
ratio_img.shape
# Out:
# (72, 394, 3)

# %% [markdown]
# # Flip the image horizontally

# %%
flip_img=cv2.flip(fix_img,1)
plt.imshow(flip_img)

# %% [markdown]
# # vertically

# %%
flip_img=cv2.flip(fix_img,0)
plt.imshow(flip_img)

# %%
type(fix_img)
# Out:
# numpy.ndarray

# %%
#save your new img using imwrite

# %%
cv2.imwrite('totally_new.jpg',fix_img)
# Out:
# True

# %%
#detect blue color from img

# %%
mg=cv2.imread('colors.jpg')
new_img=cv2.cvtColor(mg,cv2.COLOR_BGR2RGB)


hsv= cv2.cvtColor(new_img,cv2.COLOR_RGB2HSV)
lower_blue=np.array([110,50,50])
upper_blue=np.array([130,255,255])

mask=cv2.inRange(hsv,lower_blue,upper_blue)

res=cv2.bitwise_and(new_img,new_img,mask=mask)
plt.imshow(new_img)

# %%
cat=cv2.imread('cat.jpg')

# %%
plt.imshow(cat)

# %%
cat.shape
# Out:
# (1080, 1000, 3)

# %%
flags=[i for i in dir(cv2) if i.startswith('COLOR_')]
print(flags)
# Out:
# ['COLOR_BAYER_BG2BGR', 'COLOR_BAYER_BG2BGRA', 'COLOR_BAYER_BG2BGR_EA', 'COLOR_BAYER_BG2BGR_VNG', 'COLOR_BAYER_BG2GRAY', 'COLOR_BAYER_BG2RGB', 'COLOR_BAYER_BG2RGBA', 'COLOR_BAYER_BG2RGB_EA', 'COLOR_BAYER_BG2RGB_VNG', 'COLOR_BAYER_BGGR2BGR', 'COLOR_BAYER_BGGR2BGRA', 'COLOR_BAYER_BGGR2BGR_EA', 'COLOR_BAYER_BGGR2BGR_VNG', 'COLOR_BAYER_BGGR2GRAY', 'COLOR_BAYER_BGGR2RGB', 'COLOR_BAYER_BGGR2RGBA', 'COLOR_BAYER_BGGR2RGB_EA', 'COLOR_BAYER_BGGR2RGB_VNG', 'COLOR_BAYER_GB2BGR', 'COLOR_BAYER_GB2BGRA', 'COLOR_BAYER_GB2BGR_EA', 'COLOR_BAYER_GB2BGR_VNG', 'COLOR_BAYER_GB2GRAY', 'COLOR_BAYER_GB2RGB', 'COLOR_BAYER_GB2RGBA', 'COLOR_BAYER_GB2RGB_EA', 'COLOR_BAYER_GB2RGB_VNG', 'COLOR_BAYER_GBRG2BGR', 'COLOR_BAYER_GBRG2BGRA', 'COLOR_BAYER_GBRG2BGR_EA', 'COLOR_BAYER_GBRG2BGR_VNG', 'COLOR_BAYER_GBRG2GRAY', 'COLOR_BAYER_GBRG2RGB', 'COLOR_BAYER_GBRG2RGBA', 'COLOR_BAYER_GBRG2RGB_EA', 'COLOR_BAYER_GBRG2RGB_VNG', 'COLOR_BAYER_GR2BGR', 'COLOR_BAYER_GR2BGRA', 'COLOR_BAYER_GR2BGR_EA', 'COLOR_BAYER_GR2BGR_VNG', 'COLO
# ...

# %%
cat_fix=cv2.cvtColor(cat,cv2.COLOR_BayerRG2GRAY)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 cat_fix=cv2.cvtColor(cat,cv2.COLOR_BayerRG2GRAY)
#
# error: OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\demosaicing.cpp:1699: error: (-215:Assertion failed) scn == 1 && dcn == 1 in function 'cv::demosaicing'

# %%
plt.imshow(cat_fix)

# %%
new_img=cv2.resize(cat_fix,(40000,40000))

# %%
gray_img=cv2.imread('color.jpg',cv2.IMREAD_GRAYSCALE)
kernel=np.ones((6,6),np.unit8)
er=cv2.erode(gray_img,kernel,iterations=1)

plt.subplot(121),plt.imshow(gray_img,cmap='gray'),plt.titile('')
plt

# %% [markdown]
# # dilation

# %%
coins=cv2.imread('coin.jpg')
plt.imshow(coin)

# %%
coins_gray=cv2.cvtColor(coins,cv2.COLOR_BGR2GRAY)
coins_preprocessed=cv2.GaussianBlur(coins_gray,(5,5),0)
plt.imshow(cv2.cvtColor(coins_preprocessed,cv2.COLOR_GRAY2RGB))

# %%
coins_preprocessed
# Out:
# array([[252, 251, 250, ..., 246, 249, 250],
#        [251, 250, 249, ..., 245, 247, 249],
#        [250, 249, 247, ..., 242, 245, 247],
#        ...,
#        [250, 249, 247, ..., 244, 245, 246],
#        [251, 251, 250, ..., 246, 247, 247],
#        [252, 252, 251, ..., 247, 247, 247]], dtype=uint8)

# %%
_,coins_binary=cv2.threshold(coins_preprocessed,147,255,cv2.THRESH_BINARY)
coins_binary=cv2.bitwise_not(coins_binary)
plt.imshow(cv2.cvtColor(coins_binary,cv2.COLOR_GRAY2RGB))

# %%
morph_kernel=np.ones((5,5),np.uint8)
coins_morph=cv2.morphologyEx(coins_binary,cv2.MORPH_CLOSE,morph_kernel)
plt.imshow(cv2.cvtColor(coins_morph,cv2.COLOR_GRAY2RGB))

# %%
# find contours
coins_contours,_=cv2.findContours(coins_binary,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)

# make copy of image
coins_and_contours=np.copy(coins)
# find contours of large enough area
mini_coin_area =30
large_contours=[cnt for cnt in coins_contours if cv2.contourArea(cnt) > mini_coin_area]

# draw contours
cv2.drawContours(coins_and_contours,large_contours,-1,(0,0,255))

plt.imshow(cv2.cvtColor(coins_and_contours,cv2.COLOR_BGR2RGB))

# print number of contours
print("Number of coins: ",len(large_contours))
# Out:
# Number of coins:  5

# %%
bounding_img=np.copy(coins)

# %%
for contours in large_contours:
    x,y,w,h=cv2.boundingRect(contours)
    cv2.rectangle(bounding_img,(x,y),(x+y,y+h),(0,255,0),3)
plt.imshow(cv2.cvtColor(bounding_img,cv2.COLOR_GRAY2RGB))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [62], in <cell line: 4>()
#       2     x,y,w,h=cv2.boundingRect(contours)
#       3     cv2.rectangle(bounding_img,(x,y),(x+y,y+h),(0,255,0),3)
# ----> 4 plt.imshow(cv2.cvtColor(bounding_img,cv2.COLOR_GRAY2RGB))
#
# error: OpenCV(4.7.0) d:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function '__cdecl cv::impl::`anonymous-namespace'::CvtHelper<struct cv::impl::`anonymous namespace'::Set<1,-1,-1>,struct cv::impl::A0x981fb336::Set<3,4,-1>,struct cv::impl::A0x981fb336::Set<0,2,5>,2>::CvtHelper(const class cv::_InputArray &,const class cv::_OutputArray &,int)'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 3

# %%
plt.imshow(bounding_img)
