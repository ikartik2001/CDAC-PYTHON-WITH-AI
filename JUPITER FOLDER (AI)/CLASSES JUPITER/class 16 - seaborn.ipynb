# %% [markdown]
# ### sea born

# %%
import pandas
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### check in inbuilt datasets

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
# styling in sea born

param =sns.axes_style()

# %%
# sea born color pallate
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sns.color_palette('deep',19)
# Out:
# [(0.2980392156862745, 0.4470588235294118, 0.6901960784313725),
#  (0.8666666666666667, 0.5176470588235295, 0.3215686274509804),
#  (0.3333333333333333, 0.6588235294117647, 0.40784313725490196),
#  (0.7686274509803922, 0.3058823529411765, 0.3215686274509804),
#  (0.5058823529411764, 0.4470588235294118, 0.7019607843137254),
#  (0.5764705882352941, 0.47058823529411764, 0.3764705882352941),
#  (0.8549019607843137, 0.5450980392156862, 0.7647058823529411),
#  (0.5490196078431373, 0.5490196078431373, 0.5490196078431373),
#  (0.8, 0.7254901960784313, 0.4549019607843137),
#  (0.39215686274509803, 0.7098039215686275, 0.803921568627451),
#  (0.2980392156862745, 0.4470588235294118, 0.6901960784313725),
#  (0.8666666666666667, 0.5176470588235295, 0.3215686274509804),
#  (0.3333333333333333, 0.6588235294117647, 0.40784313725490196),
#  (0.7686274509803922, 0.3058823529411765, 0.3215686274509804),
#  (0.5058823529411764, 0.4470588235294118, 0.7019607843137254),
# ...

# %%
sns.color_palette('PiYG',10)
# Out:
# [(0.7514033064206075, 0.09588619761630142, 0.4736639753940792),
#  (0.8513648596693579, 0.395924644367551, 0.6446751249519416),
#  (0.9231833910034601, 0.6410611303344866, 0.804152249134948),
#  (0.9755478662053056, 0.8202998846597462, 0.9081891580161476),
#  (0.9792387543252595, 0.9279507881584006, 0.954479046520569),
#  (0.938562091503268, 0.9650903498654364, 0.8996539792387543),
#  (0.8382929642445216, 0.9331026528258363, 0.7132641291810845),
#  (0.6558246828143024, 0.8396770472895041, 0.4459054209919264),
#  (0.4595924644367551, 0.7049596309111881, 0.23029603998462128),
#  (0.2873510188389081, 0.5548635140330642, 0.1263360246059208)]

# %%
sns.color_palette('GnBu',10)
# Out:
# [(0.9035447904652056, 0.9627681660899654, 0.881753171856978),
#  (0.8436755094194541, 0.939038831218762, 0.8205920799692425),
#  (0.7767474048442907, 0.9125259515570934, 0.7622145328719724),
#  (0.6704498269896194, 0.8711880046136101, 0.7149711649365629),
#  (0.5460207612456748, 0.8240522875816993, 0.7474048442906575),
#  (0.41868512110726647, 0.7646289888504422, 0.7898500576701268),
#  (0.29457900807381776, 0.6893656286043829, 0.8206689734717416),
#  (0.19123414071510958, 0.5742099192618224, 0.7586620530565167),
#  (0.09219530949634756, 0.47040369088811995, 0.7057900807381776),
#  (0.03137254901960784, 0.36416762783544787, 0.6275586312956556)]

# %%
#relplot function

# %%
sns.relplot(data=df,x='total_bill',y='tip')

# %%
sns.relplot(data=df,x='total_bill',y='tip',hue='day')

# %%
sns.relplot(data=df,x='total_bill',y='tip',hue='sex',col='day',col_wrap=2)

# %%
sns.relplot(data=df,x='size',y='tip',kind='line',ci=None)

# %% [markdown]
# # Histograms

# %%
#histograms represents the data distribution by forming

# %%
sns.displot(df['size'])

# %%
# bar plot

sns.barplot(x='size',y='tip',data=df,palette='PuRd',ci=None);

# %%
sns.barplot(x='tip',y='day',data=df,palette='PuRd',orient='h',ci=None);

# %% [markdown]
# ## count plot

# %%
sns.countplot(x='size',hue='day',data=df,palette='magma');

# %%
sns.countplot(x='size',hue='time',data=df,palette='magma')
# Out:
# <AxesSubplot:xlabel='size', ylabel='count'>

# %%
sns.pointplot(x='day',y='tip',data=df);

# %%
sns.pointplot(x='day',y='tip',data=df)
sns.pointplot(x='time',y='total_bill',hue='smoker',data=df,palette='accent')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\seaborn\palettes.py:206, in color_palette(palette, n_colors, desat, as_cmap)
#     204 try:
#     205     # Perhaps a named matplotlib colormap?
# --> 206     palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     207 except ValueError:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\seaborn\palettes.py:443, in mpl_palette(name, n_colors, as_cmap)
#     442 else:
# --> 443     cmap = mpl.cm.get_cmap(name)
#     445 if name in MPL_QUAL_PALS:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cm.py:286, in get_cmap(name, lut)
#     285     return name
# --> 286 _api.check_in_list(sorted(_cmap_registry), name=name)
#     287 if lut is None:
#
# ...

# %% [markdown]
# #  join plot

# %%
join plot draws a plot of two variables with bivariate

sns.set_style('dark')
sns.jointplot(x='total_bill',y='tip',data=df)

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind='reg')

# %% [markdown]
# ## pair plot

# %%
sns.pairplot(df,hue='sex')

# %% [markdown]
# ### box plot and violentplot

# %%
sns.boxplot(x='day',y='total_bill',data=df)

# %%
sns.boxplot(x='day',y='total_bill',ori='h')

# %%
sns.violinplot(x='day',y='total_bill',data=df,palette='rainbow')

# %% [markdown]
# ### stripplot

# %%
sns.stripplot(x='day',y='total_bill',data=df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day',y='total_bill',data=df,jitter=False) # jitter reduces overplottings
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day',y='total_bill',data=df,jitter=False,hue='sex',dodge=True) # total bill according to gender
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day',y='total_bill',data=df,hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>
