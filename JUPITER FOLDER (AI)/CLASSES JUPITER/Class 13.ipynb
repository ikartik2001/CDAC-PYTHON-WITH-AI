# %%
import pandas as pd

# %%
sal=pd.read_csv('Salaries.csv',low_memory=False)
sal
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC         77916
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %% [markdown]
# ### CHECKING HEAD OF DATAFRAME

# %%
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18           0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3      77916    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6        9737  182234.59      NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# ...

# %% [markdown]
# ### USE THE INFO METHOD TO

# %%
sal.info()         # first step is to get its info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %% [markdown]
# ### 2nd step is to get shape

# %%
sal.shape
# Out:
# (148654, 13)

# %% [markdown]
# ### check the nul values in the dataframe

# %%
sal.isna().sum()   # checks the sum of nul values in dataframe
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %% [markdown]
# # step 1 cleaning the dataset

# %%
clean=sal.copy()   # never use original dataset , always work on copy dataset
clean.head(2)
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2    GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18           0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# 1  2011    NaN  San Francisco    NaN

# %% [markdown]
# ### Handeling the missing value

# %%
clean.drop("Notes",axis=1,inplace=True)   # since notes has null values , its better to drop it .
clean
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC         77916
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %% [markdown]
# #### NOW DROPING THE STATUS ..WITH NULL VALUES

# %%
clean.drop("Status",axis=1,inplace=True)
clean.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18           0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3      77916    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6        9737  182234.59      NaN  326373.19         326373.19
#
#    Year         Agency
# 0  2011  San Francisco
# 1  2011  San Francisco
# ...

# %%
# again checking null values
clean.isna().sum()
# Out:
# Id                      0
# EmployeeName            0
# JobTitle                0
# BasePay               605
# OvertimePay             0
# OtherPay                0
# Benefits            36159
# TotalPay                0
# TotalPayBenefits        0
# Year                    0
# Agency                  0
# dtype: int64

# %%
clean.info()  # BASE PAY IS A OBJECT TYPE BECAUSE OF NOT PROVIDED DATA
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Agency            148654 non-null  object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 12.5+ MB

# %%
clean.tail()  # checking the tail of dataframe
# Out:
#             Id   EmployeeName                    JobTitle       BasePay  \
# 148649  148650  Roy I Tillery                   Custodian             0
# 148650  148651   Not provided                Not provided  Not Provided
# 148651  148652   Not provided                Not provided  Not Provided
# 148652  148653   Not provided                Not provided  Not Provided
# 148653  148654      Joe Lopez  Counselor, Log Cabin Ranch             0
#
#          OvertimePay      OtherPay      Benefits  TotalPay  TotalPayBenefits  \
# 148649             0             0             0      0.00              0.00
# 148650  Not Provided  Not Provided  Not Provided      0.00              0.00
# 148651  Not Provided  Not Provided  Not Provided      0.00              0.00
# 148652  Not Provided  Not Provided  Not Provided      0.00              0.00
# 148653             0       -618.13             0   -618.13           -618.13
#
#         Year         Agency
# 148649  2014  San Francisco
# ...

# %%
clean.drop(clean[clean["BasePay"]=="Not Provided"].index, inplace=True)
clean["BasePay"] = clean["BasePay"].astype(float)
clean.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18           0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3   77916.00    56120.71   198306.9      NaN  332343.61         332343.61
# 4  134401.60        9737  182234.59      NaN  326373.19         326373.19
#
#    Year         Agency
# 0  2011  San Francisco
# 1  2011  San Francisco
# ...

# %%
clean.isna().sum()
# Out:
# Id                      0
# EmployeeName            0
# JobTitle                0
# BasePay               605
# OvertimePay             0
# OtherPay                0
# Benefits            36159
# TotalPay                0
# TotalPayBenefits        0
# Year                    0
# Agency                  0
# dtype: int64

# %%
clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148650 entries, 0 to 148653
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148650 non-null  int64
#  1   EmployeeName      148650 non-null  object
#  2   JobTitle          148650 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  object
#  5   OtherPay          148650 non-null  object
#  6   Benefits          112491 non-null  object
#  7   TotalPay          148650 non-null  float64
#  8   TotalPayBenefits  148650 non-null  float64
#  9   Year              148650 non-null  int64
#  10  Agency            148650 non-null  object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 13.6+ MB

# %%
# change the data type of "basepay"
convert=["BasePay","OvertimePay","OtherPay","Benefits"]
for col in convert:
    clean[col]=clean[col].astype("float64")
    
clean.head()
clean.info()  # the datatype is changed form float to object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148650 entries, 0 to 148653
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148650 non-null  int64
#  1   EmployeeName      148650 non-null  object
#  2   JobTitle          148650 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148650 non-null  float64
#  8   TotalPayBenefits  148650 non-null  float64
#  9   Year              148650 non-null  int64
#  10  Agency            148650 non-null  object
# dtypes: float64(6), int64(2), object(3)
# memory usage: 13.6+ MB

# %% [markdown]
# ### Describe the dataset

# %%
clean.describe().round(2) # give round about data of values in float
# Out:
#               Id    BasePay  OvertimePay   OtherPay   Benefits   TotalPay  \
# count  148650.00  148045.00    148650.00  148650.00  112491.00  148650.00
# mean    74325.50   66325.45      5066.06    3648.77   25007.89   74770.33
# std     42911.70   42764.64     11454.38    8056.60   15402.22   50516.20
# min         1.00    -166.01        -0.01   -7058.59     -33.89    -618.13
# 25%     37163.25   33588.20         0.00       0.00   11535.40   36169.96
# 50%     74325.50   65007.45         0.00     811.27   28628.62   71427.24
# 75%    111487.75   94691.05      4658.18    4236.07   35566.85  105842.96
# max    148654.00  319275.01    245131.88  400184.25   96570.66  567595.43
#
#        TotalPayBenefits       Year
# count         148650.00  148650.00
# mean           93695.08    2012.52
# std            62792.50       1.12
# min             -618.13    2011.00
# 25%            44073.34    2012.00
# 50%            92406.02    2013.00
# 75%           132877.99    2014.00
# ...

# %%
clean.describe(exclude="number").T   # excluding all the numbers
# Out:
#                count  unique               top    freq
# EmployeeName  148650  110810         Kevin Lee      13
# JobTitle      148650    2158  Transit Operator    7036
# Agency        148650       1     San Francisco  148650

# %% [markdown]
# ### Correlation of columns

# %%
# find the coorelation between the columns using 'corr()' function
clean.corr()
# Out:
#                         Id   BasePay  OvertimePay  OtherPay  Benefits  \
# Id                1.000000 -0.204878    -0.081505 -0.100403 -0.348957
# BasePay          -0.204878  1.000000     0.266740  0.285655  0.918028
# OvertimePay      -0.081505  0.266740     1.000000  0.316592  0.301207
# OtherPay         -0.100403  0.285655     0.316592  1.000000  0.233178
# Benefits         -0.348957  0.918028     0.301207  0.233178  1.000000
# TotalPay         -0.211424  0.954494     0.504859  0.470496  0.884097
# TotalPayBenefits -0.092127  0.946595     0.467981  0.422341  0.930140
# Year              0.968172  0.033751     0.027887 -0.002499 -0.043136
#
#                   TotalPay  TotalPayBenefits      Year
# Id               -0.211424         -0.092127  0.968172
# BasePay           0.954494          0.946595  0.033751
# OvertimePay       0.504859          0.467981  0.027887
# OtherPay          0.470496          0.422341 -0.002499
# Benefits          0.884097          0.930140 -0.043136
# ...

# %%
# check the null values in base pay
clean[clean["BasePay"].isna()]
# Out:
#             Id       EmployeeName                   JobTitle  BasePay  \
# 81391    81392    Kevin P Cashman             Deputy Chief 3      NaN
# 84506    84507  Demetrya  Mullens  Licensed Vocational Nurse      NaN
# 84960    84961    Michael M Horan        Park Patrol Officer      NaN
# 90525    90526       Thomas  Tang           Police Officer 3      NaN
# 90786    90787     Michael C Hill             Deputy Sheriff      NaN
# ...        ...                ...                        ...      ...
# 110526  110527     Arthur L Curry    PS Aide Health Services      NaN
# 110527  110528      Nereida  Vega               Senior Clerk      NaN
# 110528  110529   Timothy E Gibson           Police Officer 3      NaN
# 110529  110530     Mark E Laherty           Police Officer 3      NaN
# 110530  110531      David P Kucia           Police Officer 3      NaN
#
#         OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  \
# ...

# %%
clean["BasePay"]=clean["BasePay"].fillna(value=0)

# %%
clean["BasePay"].isna().sum()
# Out:
# 0

# %%
clean["Benefits"]=clean["Benefits"].fillna(value=0)

# %%
clean["Benefits"].isna().sum()
# Out:
# 0

# %% [markdown]
# ### check why appear

# %%
(clean["BasePay"]<10)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148645     True
# 148647     True
# 148648     True
# 148649     True
# 148653     True
# Name: BasePay, Length: 148650, dtype: bool

# %%
clean.duplicated().sum() # there is no duplicate values in clean
# Out:
# 0

# %% [markdown]
# ### save the cleaned file into csv with name clean_salary.csv

# %%
clean.to_csv("clean_salary.csv",index=False)

# %%
sal=pd.read_csv('clean_salary.csv')
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       0.0  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       0.0  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       0.0  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       0.0  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       0.0  326373.19         326373.19
#
#    Year         Agency   BaseyPay
# 0  2011  San Francisco  167411.18
# ...

# %%
sal.isna()
# Out:
#            Id  EmployeeName  JobTitle  BasePay  OvertimePay  OtherPay  \
# 0       False         False     False    False        False     False
# 1       False         False     False    False        False     False
# 2       False         False     False    False        False     False
# 3       False         False     False    False        False     False
# 4       False         False     False    False        False     False
# ...       ...           ...       ...      ...          ...       ...
# 148645  False         False     False    False        False     False
# 148646  False         False     False    False        False     False
# 148647  False         False     False    False        False     False
# 148648  False         False     False    False        False     False
# 148649  False         False     False    False        False     False
#
#         Benefits  TotalPay  TotalPayBenefits   Year  Agency  BaseyPay
# ...

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148650 entries, 0 to 148649
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148650 non-null  int64
#  1   EmployeeName      148650 non-null  object
#  2   JobTitle          148650 non-null  object
#  3   BasePay           148650 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          148650 non-null  float64
#  7   TotalPay          148650 non-null  float64
#  8   TotalPayBenefits  148650 non-null  float64
#  9   Year              148650 non-null  int64
#  10  Agency            148650 non-null  object
#  11  BaseyPay          148650 non-null  float64
# dtypes: float64(7), int64(2), object(3)
# memory usage: 13.6+ MB

# %%
sal["BasePay"].mean()
# Out:
# 66055.50671774488

# %% [markdown]
# ### what is the higest amount of overtimePay in the dataset?

# %%
sal['OvertimePay'].max()
# Out:
# 245131.88

# %% [markdown]
# ### what is the job title of JOSEPH DRISCOLL?

# %%
sal[sal['EmployeeName']=='JOSEPH DRISCOLL']['JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %% [markdown]
# ### its totalpaiybenefits ?

# %%
sal[sal['EmployeeName']=='JOSEPH DRISCOLL']['TotalPayBenefits']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# ### what is the higeset payed person (including benefits)?

# %%
sal[sal['TotalPayBenefits']==['TotalPayBenefits'].max()["EmployeeName"]
# Out:
#   Input In [202]
#     sal[sal['TotalPayBenefits']==['TotalPayBenefits'].max()["EmployeeName"]
#                                                                            ^
# SyntaxError: unexpected EOF while parsing

# %%
sal.loc[sal['TotalPayBenefits'].idxmax()]['EmployeeName']
# Out:
# 'NATHANIEL FORD'

# %% [markdown]
# ### what is the name of lowest payed person ?

# %%
sal.loc[sal['TotalPayBenefits'].idxmax()['EmployeeName']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [211], in <cell line: 1>()
# ----> 1 sal.loc[sal['TotalPayBenefits'].idxmax()['EmployeeName']]
#
# TypeError: 'int' object is not subscriptable

# %% [markdown]
# ### finding the mean sallary

# %%
sal.groupby('Year').mean()['BasePay']
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    68509.832156
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %% [markdown]
# ### how many unique job titles are there?

# %%
sal["JobTitle"].nunique() # sal["coloumn name"]   or then add .nunique() for unique job titles
# Out:
# 2158

# %%
sal[["JobTitle",'BasePay']].nunique() ## using multiople columns
# Out:
# JobTitle      2158
# BasePay     109489
# dtype: int64

# %% [markdown]
# ### what are top 5 most common jobs

# %%
sal['JobTitle'].value_counts().head(5)  # head 5 gives top 5 and head(2) gives top 2
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %% [markdown]
# ### How many people have job chief in their job title?

# %%
title=sal['JobTitle']

# %%
def chief_string(title):
    if 'chief'in title.lower():
        return True
    else:
        return False

# %%
sal['JobTitle'].apply(chief_string).sum()  # applying function on sal job title using .apply() the sum
# Out:
# 627

# %% [markdown]
# ### Total number of job titles which contains captain

# %%
len(sal[sal["JobTitle"].str.contains('CAPTAIN',case=False)])
# Out:
# 552

# %% [markdown]
# ### How many base pay allocated between different groups

# %%
sal.groupby('JobTitle')["BasePay"].mean().sort_values(ascending=False)
# Out:
# JobTitle
# Chief of Police                            309767.683333
# Chief, Fire Department                     304232.340000
# Gen Mgr, Public Trnsp Dept                 297769.413333
# CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)     285262.000000
# Dep Dir for Investments, Ret               276153.765000
#                                                ...
# PUBLIC SAFETY COMMUNICATIONS TECHNICIAN         0.000000
# Drug Court Coordinator                          0.000000
# Public Safety Comm Tech                         0.000000
# ASSISTANT RECREATION SUPERVISOR                 0.000000
# IS Technician Assistant                         0.000000
# Name: BasePay, Length: 2158, dtype: float64

# %% [markdown]
# ### Find occurance of the employe name

# %%
sal['EmployeeName'].sample(5)  # sample 5
# Out:
# 77578       Jason D Blantz
# 145998    Virginia L Perry
# 40247      Michael Dietzen
# 129380      Sharie M Canja
# 46918           Tan Nguyen
# Name: EmployeeName, dtype: object

# %%
sal['EmployeeName'].value_counts().head()  #get the maximum value count of names
# Out:
# Kevin Lee       13
# William Wong    11
# Richard Lee     11
# Steven Lee      11
# KEVIN LEE        9
# Name: EmployeeName, dtype: int64
