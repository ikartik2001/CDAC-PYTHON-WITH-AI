# %%
import cv2
import matplotlib.pyplot as plt
import time     # for speed comparison of both classifier 
# %matplotlib inline

# %%
def convertTORGB(img):
    return cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
#Haar cascade classifier

# %%
img=cv2.imread('baby.jpg')
gray_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
cv2.imshow('Test Image',gray_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(gray_img,cmap='gray')

# %%
haar_face_cascade=cv2.CascadeClassifier(r"C:\Users\keerti chouhan\anaconda3\Lib\site-packages\cv2\data/haarcascade_frontalface_alt.xml")

# %%
faces=haar_face_cascade.detectMultiScale(gray_img,scaleFactor=1.1,minNeighbors=5)
print("Faces found:",len(faces))
# Out:
# Faces found: 1

# %%
#draw the rectangles

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)   #B,G,R

# %%
plt.imshow(convertTORGB(img))    #convert imGE TO RGB AND SHOW IMaGE

# %%
path=input("enter image") 
def result(path):
    test1=cv2.imread('baby.jpg')
    gray_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    cv2.imshow('Test Image',gray_img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    plt.imshow(gray_img,cmap='gray')
    haar_face_cascade=cv2.CascadeClassifier(r"C:\Users\keerti chouhan\anaconda3\Lib\site-packages\cv2\data/haarcascade_frontalface_alt.xml")
    faces=haar_face_cascade.detectMultiScale(gray_img,scaleFactor=1.1,minNeighbors=5)
    print("Faces found:",len(faces))     
    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
    plt.imshow(convertTORGB(img))
    
result(path)
# Out:
# enter imagebaby.jpg
# Faces found: 1

# %%
path=input("enter image") 
def result(path):
    test2=cv2.imread('group.jpg')
    gray_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    cv2.imshow('Test Image',gray_img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    plt.imshow(gray_img,cmap='gray')
    haar_face_cascade=cv2.CascadeClassifier(r"C:\Users\keerti chouhan\anaconda3\Lib\site-packages\cv2\data/haarcascade_frontalface_alt.xml")
    faces=haar_face_cascade.detectMultiScale(gray_img,scaleFactor=1.1,minNeighbors=5)
    print("Faces found:",len(faces))     
    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
    plt.imshow(convertTORGB(img))
    
result(path)
# Out:
# enter image'group.jpg'
# Faces found: 5

# %%
#Face Detection and count application data

#Face detection function
def detect_faces(f_cascade, colored_img, scaleFactor = 1.3):
    #just making a copy of image passed, so that
    #passed image is not changed
    img_copy = colored_img.copy()
   
    #convert the test image to gray image as opencv
    #face detector expects gray images
    gray = cv2.cvtColor(img_copy, cv2.COLOR_BGR2GRAY)
   
    #let's detect multiscale (some images may be closer to camera than others) images
    faces = f_cascade.detectMultiScale(gray,
                                       scaleFactor=scaleFactor,
                                       minNeighbors=5);
   
   
    #print the number of faces found
    print('Faces found: ', len(faces))
   
    #go over list of faces and draw them as rectangles on original colored img
    for (x, y, w, h) in faces:
        cv2.rectangle(img_copy, (x, y), (x+w, y+h), (0, 255, 0), 2)
       
    return img_copy

# %%
lbp_face_cascade=cv2.CascadeClassifier(r"C:\Users\keerti chouhan\Downloads\lbpcascade_frontalface.xml")
test1=cv2.imread("group.jpg")
face_detected_img= detect_faces(lbp_face_cascade , test1)
plt.imshow(convertTORGB(face_detected_img))
# Out:
# Faces found:  5

# %%
#Time difference for haar cascade and lbp cascade

#------------HAAR-----------
#note time before detection
t1 = time.time()

#call our function to detect faces
haar_detected_img = detect_faces(haar_face_cascade, test1)

#note time after detection
t2 = time.time()
#calculate time difference
dt1 = t2 - t1



#show images
# plt.imshow(faces_detected_img)
#print the time differene
# Out:
# Faces found:  5

# %%
t1 = time.time()

#call our function to detect faces
lbp_detected_img = detect_faces(lbp_face_cascade, test1)

#note time after detection
t2 = time.time()
#calculate time difference
dt2 = t2 - t1
#Plot both on matplotlib
# Out:
# Faces found:  5

# %%
#Plot both on matplotlib

#create a figure of 2 plots (one for Haar and one for LBP)
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

#show Haar image
ax1.set_title('Haar Detection time: ' + str(round(dt1, 3)) + ' secs')
ax1.imshow(convertTORGB(haar_detected_img))

#show LBP image
ax2.set_title('LBP Detection time: ' + str(round(dt2, 3)) + ' secs')
ax2.imshow(convertTORGB(lbp_detected_img))
