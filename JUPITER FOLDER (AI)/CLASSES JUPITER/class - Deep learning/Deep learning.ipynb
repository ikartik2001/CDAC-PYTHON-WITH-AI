# %% [markdown]
# ## Deep learning class

# %% [markdown]
# ![deep-learning-example.png](attachment:deep-learning-example.png)

# %% [markdown]
# <div>
#     <img src="attachment:Screenshot.png" width="500"/>
# </div>

# %% [raw]
# What is deep learning? Deep learning is a subset of machine learning, which is essentially a neural network with three or more layers. These neural networks attempt to simulate the behavior of the human brain—albeit far from matching its ability—allowing it to “learn” from large amounts of data.

# %% [markdown]
# ![download.jpg](attachment:download.jpg)

# %% [markdown]
# neural network background coding

# %%
class neuron():
    def __init__(self):
        self.input_layer_size=2
        self.hidden_layer_size=2
        self.output_layer_size=1
        
        self.weights_hidden=np.random.randn(self.input_layer_size,self.hidden_layer_size)
        self.weights_output=np.random.randn(self.hidden_layer_size,self.output_layer_size)
        
        self.bias_hidden=np.array([0,0])
        self.bias_output=np.array([-0.5])
        
        def forward(self,x):
            self.hidden_layer = sigmoid(np.dot(x,self.weights_hidden)+self.bias_hidden)
            self.output_layer= sigmoid(np.dot(self.hidden_layer,self.weights_output))

# %%
x= [1,2,3,4]

# %%
neuron = neuron()

# %%
output_data =neuron.forward(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [129], in <cell line: 1>()
# ----> 1 output_data =neuron.forward(x)
#
# AttributeError: 'neuron' object has no attribute 'forward'
